# %% [markdown]
# # Files
#
# A brief tutorial on how to read in data from files.
#
# To setup this project we have a root directory with a files directory containing 2 files: test.txt and names.csv which are at the bottom of this tutorial.

# %%
import os
#select current dir
currentDir = os.getcwd()
currentDir = os.path.join(currentDir)
#our file name
tFile: str = "test.txt"
#create absolute path to file
absFilePath: str = os.path.join(currentDir, tFile)
#oper file reader in read mode
f = open(absFilePath, 'r')
#print file name
print(f.mode)


#close file reader  !! very important
f.close()

#context manager automatically closes file for us
with open(absFilePath, 'r') as ff:
    # ffContents = ff.read()
    # print(ffContents)
    # select size of read in characters
    #SIZE: int = 100
    #ffContents = ff.read(SIZE)

    #read one line nad move to the next
    # ffLine = ff.readline()
    # print(ffLine)

    #read all lines
    # ffLines = ff.readlines()
    #this is a list of all the lines
    # print(ffLines)

    #read all lines using for loop
    for line in ff:
        print(line, end='')


""" csv """

import csv

#our file name
cFile: str = "names.csv"
#create absolute path to file
absFilePath: str = os.path.join(currentDir, cFile)
#open file
with open(absFilePath, 'r') as csvFile:
    csvReader = csv.reader(csvFile)
    #csv.reader(file, delimeter=";") to change delimiter

    print(csvReader)
    #just an object in memory

    #skip header  (remember iterators? :)
    next(csvReader)
    #loop to read
    for line in csvReader:
        print('Hello ' + line[0] + " " + line[1])
        print('Sending email to: ' + line[2])
        # notice that line is a list already
# Out:
# r
# 1) This is a test file
# 2) With multiple lines of data...
# 3) Third line
# 4) Fourth line
# 5) Fifth line
# 6) Sixth line
# 7) Seventh line
# 8) Eighth line
# 9) Ninth line
# 10) Tenth line<_csv.reader object at 0x1059b4d60>
# Hello John Doe
# Sending email to: john-doe@bogusemail.com
# Hello Mary Smith-Robinson
# Sending email to: maryjacobs@bogusemail.com
# Hello Dave Smith
# Sending email to: davesmith@bogusemail.com
# Hello Jane Stuart
# Sending email to: janestuart@bogusemail.com
# Hello Tom Wright
# Sending email to: tomwright@bogusemail.com
# Hello Steve Robinson
# Sending email to: steverobinson@bogusemail.com
# Hello Nicole Jacobs
# Sending email to: nicolejacobs@bogusemail.com
# Hello Jane Wright
# Sending email to: janewright@bogusemail.com
# Hello Jane Doe
# Sending email to: janedoe@bogusemail.com
# Hello Kurt Wright
# Sending email to: kurtwright@bogusemail.com
# Hello Kurt Robinson
# Sending email to: kurtrobinson@bogusemail.com
# Hello Jane Jenkins
# Sending email to: janejenkins@bogusemail.com
# Hello Neil Robinson
# Sending email to: neilrobinson@bogusemail.com
# Hello Tom Patterson
# Sending email to: tompatterson@bogusemail.com
# Hello Sam Jenkins
# Sending email to: samjenkins@bogusemail.com
# Hello Steve Stuart
# Sending email to: stevestuart@bogusemail.com
# Hello Maggie Patterson
# Sending email to: maggiepatterson@bogusemail.com
# Hello Maggie Stuart
# Sending email to: maggiestuart@bogusemail.com
# Hello Jane Doe
# Sending email to: janedoe@bogusemail.com
# Hello Steve Patterson
# Sending email to: stevepatterson@bogusemail.com
# Hello Dave Smith
# Sending email to: davesmith@bogusemail.com
# Hello Sam Wilks
# Sending email to: samwilks@bogusemail.com
# Hello Kurt Jefferson
# Sending email to: kurtjefferson@bogusemail.com
# Hello Sam Stuart
# Sending email to: samstuart@bogusemail.com
# Hello Jane Stuart
# Sending email to: janestuart@bogusemail.com
# Hello Dave Davis
# Sending email to: davedavis@bogusemail.com
# Hello Sam Patterson
# Sending email to: sampatterson@bogusemail.com
# Hello Tom Jefferson
# Sending email to: tomjefferson@bogusemail.com
# Hello Jane Stuart
# Sending email to: janestuart@bogusemail.com
# Hello Maggie Jefferson
# Sending email to: maggiejefferson@bogusemail.com
# Hello Mary Wilks
# Sending email to: marywilks@bogusemail.com
# Hello Neil Patterson
# Sending email to: neilpatterson@bogusemail.com
# Hello Corey Davis
# Sending email to: coreydavis@bogusemail.com
# Hello Steve Jacobs
# Sending email to: stevejacobs@bogusemail.com
# Hello Jane Jenkins
# Sending email to: janejenkins@bogusemail.com
# Hello John Jacobs
# Sending email to: johnjacobs@bogusemail.com
# Hello Neil Smith
# Sending email to: neilsmith@bogusemail.com
# Hello Corey Wilks
# Sending email to: coreywilks@bogusemail.com
# Hello Corey Smith
# Sending email to: coreysmith@bogusemail.com
# Hello Mary Patterson
# Sending email to: marypatterson@bogusemail.com
# Hello Jane Stuart
# Sending email to: janestuart@bogusemail.com
# Hello Travis Arnold
# Sending email to: travisarnold@bogusemail.com
# Hello John Robinson
# Sending email to: johnrobinson@bogusemail.com
# Hello Travis Arnold
# Sending email to: travisarnold@bogusemail.com
